# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
song = pd.read_csv("C:/Users/Hp/Downloads/spotify_tracks_metadata.csv/spotify_tracks_metadata.csv")

# %%
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439893 entries, 0 to 439892
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Unnamed: 0               439893 non-null  int64
#  1   spotify_id               439893 non-null  object
#  2   song_name                439891 non-null  object
#  3   artist_name              439884 non-null  object
#  4   song_popularity          439893 non-null  int64
#  5   album_release_date       439893 non-null  object
#  6   album_release_year       439690 non-null  float64
#  7   album_release_month      420559 non-null  float64
#  8   analysis_url             439893 non-null  object
#  9   acousticness             439893 non-null  float64
#  10  danceability             439893 non-null  float64
#  11  duration_ms              439893 non-null  float64
#  12  energy                   439893 non-null  float64
# ...

# %%
song.isnull().sum()
# Out:
# Unnamed: 0                     0
# spotify_id                     0
# song_name                      2
# artist_name                    9
# song_popularity                0
# album_release_date             0
# album_release_year           203
# album_release_month        19334
# analysis_url                   0
# acousticness                   0
# danceability                   0
# duration_ms                    0
# energy                         0
# instrumentalness               0
# key                            0
# liveness                       0
# loudness                       0
# mode                           0
# song_explicit                  0
# speechiness                    0
# tempo                          0
# time_signature                 0
# total_available_markets        0
# track_href                     0
# uri                            0
# valence                        0
# dtype: int64

# %%
unique_artists = song["artist_name"].nunique()

# %%
unique_artists
# Out:
# 124471

# %%
unique_songs = song["song_name"].nunique()
unique_songs
# Out:
# 374226

# %%
song.describe()
# Out:
#          Unnamed: 0  song_popularity  album_release_year  album_release_month  \
# count  439893.00000    439893.000000       439690.000000        420559.000000
# mean   219946.00000        22.809390         2014.952946             6.155396
# std    126986.31532        18.518437           17.427527             3.711844
# min         0.00000         0.000000            0.000000             1.000000
# 25%    109973.00000         7.000000         2014.000000             3.000000
# 50%    219946.00000        20.000000         2018.000000             6.000000
# 75%    329919.00000        36.000000         2020.000000            10.000000
# max    439892.00000       100.000000         2021.000000            12.000000
#
#         acousticness   danceability   duration_ms         energy  \
# count  439893.000000  439893.000000  4.398930e+05  439893.000000
# mean        0.332647       0.616870  2.133885e+05       0.584848
# std         0.320389       0.178007  1.239932e+05       0.249089
# ...

# %%
song = song.drop(["Unnamed: 0", "album_release_year", "album_release_month"], axis=1)

# %%
song.isnull().sum()
# Out:
# spotify_id                 0
# song_name                  2
# artist_name                9
# song_popularity            0
# album_release_date         0
# analysis_url               0
# acousticness               0
# danceability               0
# duration_ms                0
# energy                     0
# instrumentalness           0
# key                        0
# liveness                   0
# loudness                   0
# mode                       0
# song_explicit              0
# speechiness                0
# tempo                      0
# time_signature             0
# total_available_markets    0
# track_href                 0
# uri                        0
# valence                    0
# dtype: int64

# %%
song.set_index("album_release_date",inplace=True)

# %%
song.head()
# Out:
#                                 spotify_id               song_name  \
# album_release_date
# 2021-01-08          7lPN2DXiMsVn7XUKtOW1CS         drivers license
# 2020-03-20          5QO79kh1waicV47BqGRL3g         Save Your Tears
# 2020-03-20          0VjIjW4GlUZAMYd2vXMi3b         Blinding Lights
# 2020-07-24          3tjFYV6RSFtuktYl3ZtYcq  Mood (feat. iann dior)
# 2020-11-06          27OeeYzk6klgBh83TSvGMA             WITHOUT YOU
#
#                        artist_name  song_popularity  \
# album_release_date
# 2021-01-08          Olivia Rodrigo              100
# 2020-03-20              The Weeknd               96
# 2020-03-20              The Weeknd               96
# 2020-07-24                24kGoldn               95
# 2020-11-06           The Kid LAROI               94
#
#                                                          analysis_url  \
# album_release_date
# 2021-01-08          https://api.spotify.com/v1/audio-analysis/7lPN...
# ...

# %%
song = song.drop(["track_href", "uri", "analysis_url"], axis=1)

# %%
song.head()
# Out:
#                                 spotify_id               song_name  \
# album_release_date
# 2021-01-08          7lPN2DXiMsVn7XUKtOW1CS         drivers license
# 2020-03-20          5QO79kh1waicV47BqGRL3g         Save Your Tears
# 2020-03-20          0VjIjW4GlUZAMYd2vXMi3b         Blinding Lights
# 2020-07-24          3tjFYV6RSFtuktYl3ZtYcq  Mood (feat. iann dior)
# 2020-11-06          27OeeYzk6klgBh83TSvGMA             WITHOUT YOU
#
#                        artist_name  song_popularity  acousticness  \
# album_release_date
# 2021-01-08          Olivia Rodrigo              100       0.72100
# 2020-03-20              The Weeknd               96       0.02120
# 2020-03-20              The Weeknd               96       0.00146
# 2020-07-24                24kGoldn               95       0.22100
# 2020-11-06           The Kid LAROI               94       0.21300
#
#                     danceability  duration_ms  energy  instrumentalness   key  \
# album_release_date
# ...

# %%
song.to_csv (r'C:\Users\Hp\Desktop\song1.csv')

# %%
song
# Out:
#                                 spotify_id  \
# album_release_date
# 2021-01-08          7lPN2DXiMsVn7XUKtOW1CS
# 2020-03-20          5QO79kh1waicV47BqGRL3g
# 2020-03-20          0VjIjW4GlUZAMYd2vXMi3b
# 2020-07-24          3tjFYV6RSFtuktYl3ZtYcq
# 2020-11-06          27OeeYzk6klgBh83TSvGMA
# ...                                    ...
# 2021-03-01          4JC8B6ysYqjYHYgWS2LXD1
# 2021-02-25          4MXJGhB29ow0ioRyVtdAO4
# 2021-03-09          58Su3ZNDTIzK2whzWK9wla
# 2021-03-04          28QFQkEDBCLczY6CXoxmXb
# 2020-09-07          3lGPQlCipYRcjImggeRRjE
#
#                                                             song_name  \
# album_release_date
# 2021-01-08                                            drivers license
# 2020-03-20                                            Save Your Tears
# 2020-03-20                                            Blinding Lights
# 2020-07-24                                     Mood (feat. iann dior)
# ...
